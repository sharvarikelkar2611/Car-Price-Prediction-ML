# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pickle as pkl

# %%
company= input("Enter Company Name")
name = input ("Enter Car Model")
year = int(input("Enter year of manufacturing"))
kms_driven= int(input("Enter kms running"))
fuel_type=input("Enter Fuel Type")
# Out:
# Enter Company Name Hyundai
# Enter Car Model Verna Transform SX VTVT
# Enter year of manufacturing 2020
# Enter kms running 50000
# Enter Fuel Type Petrol

# %%
input = pd.DataFrame(data=[[name, company, year, kms_driven, fuel_type]], columns=['name', 'company', 'year', 'kms_driven', 'fuel_type'])
input
# Out:
#                       name  company  year  kms_driven fuel_type
# 0  Verna Transform SX VTVT  Hyundai  2020       50000    Petrol

# %%
pipe=pkl.load(open("CPP.pkl", "rb+"))

# %%
pipe.predict(input)
# Out:
# array([[467965.20341926]])
